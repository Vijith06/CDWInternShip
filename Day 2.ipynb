# %% [markdown]
# Using count vector

# %%
import nltk
nltk.download('stopwords')
paragraph =  """I have three visions for India. In 3000 years of our history, people from all over
               the world have come and invaded us, captured our lands, conquered our minds.
               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,
               the French, the Dutch, all of them came and looted us, took over what was ours.
               Yet we have not done this to any other nation. We have not conquered anyone.
               We have not grabbed their land, their culture,
               their history and tried to enforce our way of life on them.
               Why? Because we respect the freedom of others.That is why my
               first vision is that of freedom. I believe that India got its first vision of
               this in 1857, when we started the War of Independence. It is this freedom that
               we must protect and nurture and build on. If we are not free, no one will respect us.
               My second vision for India’s development. For fifty years we have been a developing nation.
               It is time we see ourselves as a developed nation. We are among the top 5 nations of the world
               in terms of GDP. We have a 10 percent growth rate in most areas. Our poverty levels are falling.
               Our achievements are being globally recognised today. Yet we lack the self-confidence to
               see ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect?
               I have a third vision. India must stand up to the world. Because I believe that unless India
               stands up to the world, no one will respect us. Only strength respects strength. We must be
               strong not only as a military power but also as an economic power. Both must go hand-in-hand.
               My good fortune was to have worked with three great minds. Dr. Vikram Sarabhai of the Dept. of
               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.
               I was lucky to have worked with all three of them closely and consider this the great opportunity of my life.
               I see four milestones in my career"""
# Cleaning the texts
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
ps = PorterStemmer()
wordnet=WordNetLemmatizer()
sentences = nltk.sent_tokenize(paragraph)
#sentences = ['he is a good boy','she is a good girl','boy & girl are good']
corpus = []
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
 ##cv = CountVectorizer(max_features=100)
cv = CountVectorizer(max_features=500,ngram_range=(1,3))
X = cv.fit_transform(corpus).toarray()
cv.vocabulary_
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vijit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'three': np.int64(281),
#  'vision': np.int64(312),
#  'india': np.int64(137),
#  'three vision': np.int64(286),
#  'vision india': np.int64(314),
#  'three vision india': np.int64(287),
#  'year': np.int64(333),
#  'histori': np.int64(130),
#  'peopl': np.int64(204),
#  'world': np.int64(326),
#  'come': np.int64(37),
#  'invad': np.int64(145),
#  'us': np.int64(305),
#  'captur': np.int64(30),
#  'land': np.int64(151),
#  'conquer': np.int64(43),
#  'mind': np.int64(171),
#  'year histori': np.int64(336),
#  'histori peopl': np.int64(131),
#  'peopl world': np.int64(205),
#  'world come': np.int64(327),
#  'come invad': np.int64(38),
#  'invad us': np.int64(146),
#  'us captur': np.int64(306),
#  'captur land': np.int64(31),
#  'land conquer': np.int64(152),
#  'conquer mind': np.int64(45),
#  'year histori peopl': np.int64(337),
#  'histori peopl world': np.int64(132),
#  'peopl world come': np.int64(206),
#  'world come invad': np.int64(328),
#  'come invad us': np.int64(39),
#  'invad us captur': np.int64(147),
#  'us captur land': np.int64(307),
#  'captur land conquer': np.int64(32),
#  'land conquer mind': np.int64(153),
#  'alexand': np.int64(3),
#  'onward': np.int64(196),
#  'greek': np.int64(122),
#  'turk': np.int64(299),
#  'mogul': np.int64(172),
#  'portugues': np.int64(210),
#  'british': np.int64(23),
#  'french': np.int64(99),
#  'dutch': np.int64(66),
#  'came': np.int64(27),
#  'loot': np.int64(159),
#  'took': np.int64(292),
#  'alexand onward': np.int64(4),
#  'onward greek': np.int64(197),
#  'greek turk': np.int64(123),
#  'turk mogul': np.int64(300),
#  'mogul portugues': np.int64(173),
#  'portugues british': np.int64(211),
#  'british french': np.int64(24),
#  'french dutch': np.int64(100),
#  'dutch came': np.int64(67),
#  'came loot': np.int64(28),
#  'loot us': np.int64(160),
#  'us took': np.int64(308),
#  'alexand onward greek': np.int64(5),
#  'onward greek turk': np.int64(198),
#  'greek turk mogul': np.int64(124),
#  'turk mogul portugues': np.int64(301),
#  'mogul portugues british': np.int64(174),
#  'portugues british french': np.int64(212),
#  'british french dutch': np.int64(25),
#  'french dutch came': np.int64(101),
#  'dutch came loot': np.int64(68),
#  'came loot us': np.int64(29),
#  'loot us took': np.int64(161),
#  'yet': np.int64(338),
#  'done': np.int64(59),
#  'nation': np.int64(184),
#  'yet done': np.int64(339),
#  'done nation': np.int64(60),
#  'yet done nation': np.int64(340),
#  'anyon': np.int64(12),
#  'conquer anyon': np.int64(44),
#  'grab': np.int64(115),
#  'cultur': np.int64(49),
#  'tri': np.int64(296),
#  'enforc': np.int64(71),
#  'way': np.int64(320),
#  'life': np.int64(158),
#  'grab land': np.int64(116),
#  'land cultur': np.int64(154),
#  'cultur histori': np.int64(50),
#  'histori tri': np.int64(133),
#  'tri enforc': np.int64(297),
#  'enforc way': np.int64(72),
#  'way life': np.int64(321),
#  'grab land cultur': np.int64(117),
#  'land cultur histori': np.int64(155),
#  'cultur histori tri': np.int64(51),
#  'histori tri enforc': np.int64(134),
#  'tri enforc way': np.int64(298),
#  'enforc way life': np.int64(73),
#  'respect': np.int64(235),
#  'freedom': np.int64(94),
#  'other': np.int64(201),
#  'first': np.int64(81),
#  'respect freedom': np.int64(236),
#  'freedom other': np.int64(97),
#  'other first': np.int64(202),
#  'first vision': np.int64(82),
#  'vision freedom': np.int64(313),
#  'respect freedom other': np.int64(237),
#  'freedom other first': np.int64(98),
#  'other first vision': np.int64(203),
#  'first vision freedom': np.int64(83),
#  'believ': np.int64(15),
#  'got': np.int64(112),
#  'start': np.int64(265),
#  'war': np.int64(318),
#  'independ': np.int64(136),
#  'believ india': np.int64(16),
#  'india got': np.int64(139),
#  'got first': np.int64(113),
#  'vision start': np.int64(316),
#  'start war': np.int64(266),
#  'war independ': np.int64(319),
#  'believ india got': np.int64(17),
#  'india got first': np.int64(140),
#  'got first vision': np.int64(114),
#  'first vision start': np.int64(84),
#  'vision start war': np.int64(317),
#  'start war independ': np.int64(267),
#  'must': np.int64(175),
#  'protect': np.int64(225),
#  'nurtur': np.int64(191),
#  'build': np.int64(26),
#  'freedom must': np.int64(95),
#  'must protect': np.int64(178),
#  'protect nurtur': np.int64(226),
#  'nurtur build': np.int64(192),
#  'freedom must protect': np.int64(96),
#  'must protect nurtur': np.int64(179),
#  'protect nurtur build': np.int64(227),
#  'free': np.int64(91),
#  'one': np.int64(193),
#  'free one': np.int64(92),
#  'one respect': np.int64(194),
#  'respect us': np.int64(239),
#  'free one respect': np.int64(93),
#  'one respect us': np.int64(195),
#  'second': np.int64(245),
#  'develop': np.int64(53),
#  'second vision': np.int64(246),
#  'india develop': np.int64(138),
#  'second vision india': np.int64(247),
#  'vision india develop': np.int64(315),
#  'fifti': np.int64(78),
#  'fifti year': np.int64(79),
#  'year develop': np.int64(334),
#  'develop nation': np.int64(54),
#  'fifti year develop': np.int64(80),
#  'year develop nation': np.int64(335),
#  'time': np.int64(288),
#  'see': np.int64(248),
#  'time see': np.int64(289),
#  'see develop': np.int64(249),
#  'time see develop': np.int64(290),
#  'see develop nation': np.int64(250),
#  'among': np.int64(9),
#  'top': np.int64(293),
#  'term': np.int64(277),
#  'gdp': np.int64(102),
#  'among top': np.int64(10),
#  'top nation': np.int64(294),
#  'nation world': np.int64(187),
#  'world term': np.int64(331),
#  'term gdp': np.int64(278),
#  'among top nation': np.int64(11),
#  'top nation world': np.int64(295),
#  'nation world term': np.int64(188),
#  'world term gdp': np.int64(332),
#  'percent': np.int64(207),
#  'growth': np.int64(125),
#  'rate': np.int64(228),
#  'area': np.int64(13),
#  'percent growth': np.int64(208),
#  'growth rate': np.int64(126),
#  'rate area': np.int64(229),
#  'percent growth rate': np.int64(209),
#  'growth rate area': np.int64(127),
#  'poverti': np.int64(213),
#  'level': np.int64(156),
#  'fall': np.int64(74),
#  'poverti level': np.int64(214),
#  'level fall': np.int64(157),
#  'poverti level fall': np.int64(215),
#  'achiev': np.int64(0),
#  'global': np.int64(103),
#  'recognis': np.int64(230),
#  'today': np.int64(291),
#  'achiev global': np.int64(1),
#  'global recognis': np.int64(104),
#  'recognis today': np.int64(231),
#  'achiev global recognis': np.int64(2),
#  'global recognis today': np.int64(105),
#  'lack': np.int64(148),
#  'self': np.int64(253),
#  'confid': np.int64(40),
#  'reliant': np.int64(232),
#  'assur': np.int64(14),
#  'yet lack': np.int64(341),
#  'lack self': np.int64(149),
#  'self confid': np.int64(255),
#  'confid see': np.int64(41),
#  'nation self': np.int64(185),
#  'self reliant': np.int64(257),
#  'reliant self': np.int64(233),
#  'self assur': np.int64(254),
#  'yet lack self': np.int64(342),
#  'lack self confid': np.int64(150),
#  'self confid see': np.int64(256),
#  'confid see develop': np.int64(42),
#  'develop nation self': np.int64(55),
#  'nation self reliant': np.int64(186),
#  'self reliant self': np.int64(258),
#  'reliant self assur': np.int64(234),
#  'incorrect': np.int64(135),
#  'third': np.int64(279),
#  'third vision': np.int64(280),
#  'stand': np.int64(262),
#  'india must': np.int64(141),
#  'must stand': np.int64(180),
#  'stand world': np.int64(263),
#  'india must stand': np.int64(142),
#  'must stand world': np.int64(181),
#  'unless': np.int64(302),
#  'believ unless': np.int64(18),
#  'unless india': np.int64(303),
#  'india stand': np.int64(143),
#  'world one': np.int64(329),
#  'believ unless india': np.int64(19),
#  'unless india stand': np.int64(304),
#  'india stand world': np.int64(144),
#  'stand world one': np.int64(264),
#  'world one respect': np.int64(330),
#  'strength': np.int64(268),
#  'strength respect': np.int64(269),
#  'respect strength': np.int64(238),
#  'strength respect strength': np.int64(270),
#  'strong': np.int64(271),
#  'militari': np.int64(168),
#  'power': np.int64(216),
#  'also': np.int64(6),
#  'econom': np.int64(69),
#  'must strong': np.int64(182),
#  'strong militari': np.int64(272),
#  'militari power': np.int64(169),
#  'power also': np.int64(217),
#  'also econom': np.int64(7),
#  'econom power': np.int64(70),
#  'must strong militari': np.int64(183),
#  'strong militari power': np.int64(273),
#  'militari power also': np.int64(170),
#  'power also econom': np.int64(218),
#  'also econom power': np.int64(8),
#  'go': np.int64(106),
#  'hand': np.int64(128),
#  'must go': np.int64(176),
#  'go hand': np.int64(107),
#  'hand hand': np.int64(129),
#  'must go hand': np.int64(177),
#  'go hand hand': np.int64(108),
#  'good': np.int64(109),
#  'fortun': np.int64(85),
#  'work': np.int64(322),
#  'great': np.int64(118),
#  'good fortun': np.int64(110),
#  'fortun work': np.int64(86),
#  'work three': np.int64(323),
#  'three great': np.int64(284),
#  'great mind': np.int64(119),
#  'good fortun work': np.int64(111),
#  'fortun work three': np.int64(87),
#  'work three great': np.int64(325),
#  'three great mind': np.int64(285),
#  'dr': np.int64(61),
#  'vikram': np.int64(309),
#  'sarabhai': np.int64(240),
#  'dept': np.int64(52),
#  'dr vikram': np.int64(64),
#  'vikram sarabhai': np.int64(310),
#  'sarabhai dept': np.int64(241),
#  'dr vikram sarabhai': np.int64(65),
#  'vikram sarabhai dept': np.int64(311),
#  'space': np.int64(259),
#  'professor': np.int64(222),
#  'satish': np.int64(242),
#  'dhawan': np.int64(56),
#  'succeed': np.int64(274),
#  'brahm': np.int64(20),
#  'prakash': np.int64(219),
#  'father': np.int64(75),
#  'nuclear': np.int64(189),
#  'materi': np.int64(165),
#  'space professor': np.int64(260),
#  'professor satish': np.int64(223),
#  'satish dhawan': np.int64(243),
#  'dhawan succeed': np.int64(57),
#  'succeed dr': np.int64(275),
#  'dr brahm': np.int64(62),
#  'brahm prakash': np.int64(21),
#  'prakash father': np.int64(220),
#  'father nuclear': np.int64(76),
#  'nuclear materi': np.int64(190),
#  'space professor satish': np.int64(261),
#  'professor satish dhawan': np.int64(224),
#  'satish dhawan succeed': np.int64(244),
#  'dhawan succeed dr': np.int64(58),
#  'succeed dr brahm': np.int64(276),
#  'dr brahm prakash': np.int64(63),
#  'brahm prakash father': np.int64(22),
#  'prakash father nuclear': np.int64(221),
#  'father nuclear materi': np.int64(77),
#  'lucki': np.int64(162),
#  'close': np.int64(34),
#  'consid': np.int64(46),
#  'opportun': np.int64(199),
#  'lucki work': np.int64(163),
#  'three close': np.int64(282),
#  'close consid': np.int64(35),
#  'consid great': np.int64(47),
#  'great opportun': np.int64(120),
#  'opportun life': np.int64(200),
#  'lucki work three': np.int64(164),
#  'work three close': np.int64(324),
#  'three close consid': np.int64(283),
#  'close consid great': np.int64(36),
#  'consid great opportun': np.int64(48),
#  'great opportun life': np.int64(121),
#  'four': np.int64(88),
#  'mileston': np.int64(166),
#  'career': np.int64(33),
#  'see four': np.int64(251),
#  'four mileston': np.int64(89),
#  'mileston career': np.int64(167),
#  'see four mileston': np.int64(252),
#  'four mileston career': np.int64(90)}

# %% [markdown]
# TFidF

# %%
import nltk
nltk.download('stopwords')
paragraph =  """I have three visions for India. In 3000 years of our history, people from all over
               the world have come and invaded us, captured our lands, conquered our minds.
               From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,
               the French, the Dutch, all of them came and looted us, took over what was ours.
               Yet we have not done this to any other nation. We have not conquered anyone.
               We have not grabbed their land, their culture,
               their history and tried to enforce our way of life on them.
               Why? Because we respect the freedom of others.That is why my
               first vision is that of freedom. I believe that India got its first vision of
               this in 1857, when we started the War of Independence. It is this freedom that
               we must protect and nurture and build on. If we are not free, no one will respect us.
               My second vision for India’s development. For fifty years we have been a developing nation.
               It is time we see ourselves as a developed nation. We are among the top 5 nations of the world
               in terms of GDP. We have a 10 percent growth rate in most areas. Our poverty levels are falling.
               Our achievements are being globally recognised today. Yet we lack the self-confidence to
               see ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect?
               I have a third vision. India must stand up to the world. Because I believe that unless India
               stands up to the world, no one will respect us. Only strength respects strength. We must be
               strong not only as a military power but also as an economic power. Both must go hand-in-hand.
               My good fortune was to have worked with three great minds. Dr. Vikram Sarabhai of the Dept. of
               space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.
               I was lucky to have worked with all three of them closely and consider this the great opportunity of my life.
               I see four milestones in my career"""
# Cleaning the texts
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
ps = PorterStemmer()
wordnet=WordNetLemmatizer()
sentences = nltk.sent_tokenize(paragraph)
#sentences = ['he is a good boy','she is a good girl','boy & girl are good']
corpus = []
for i in range(len(sentences)):
    review = re.sub('[^a-zA-Z]', ' ', sentences[i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer()
X = cv.fit_transform(corpus).toarray()
cv.vocabulary_
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vijit\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'three': 96,
#  'vision': 106,
#  'india': 50,
#  'year': 111,
#  'histori': 47,
#  'peopl': 71,
#  'world': 110,
#  'come': 15,
#  'invad': 51,
#  'us': 104,
#  'captur': 12,
#  'land': 53,
#  'conquer': 17,
#  'mind': 61,
#  'alexand': 1,
#  'onward': 68,
#  'greek': 44,
#  'turk': 102,
#  'mogul': 62,
#  'portugues': 73,
#  'british': 9,
#  'french': 36,
#  'dutch': 25,
#  'came': 11,
#  'loot': 56,
#  'took': 99,
#  'yet': 112,
#  'done': 23,
#  'nation': 64,
#  'anyon': 4,
#  'grab': 42,
#  'cultur': 19,
#  'tri': 101,
#  'enforc': 27,
#  'way': 108,
#  'life': 55,
#  'respect': 82,
#  'freedom': 35,
#  'other': 70,
#  'first': 31,
#  'believ': 7,
#  'got': 41,
#  'start': 90,
#  'war': 107,
#  'independ': 49,
#  'must': 63,
#  'protect': 78,
#  'nurtur': 66,
#  'build': 10,
#  'free': 34,
#  'one': 67,
#  'second': 85,
#  'develop': 21,
#  'fifti': 30,
#  'time': 97,
#  'see': 86,
#  'among': 3,
#  'top': 100,
#  'term': 94,
#  'gdp': 37,
#  'percent': 72,
#  'growth': 45,
#  'rate': 79,
#  'area': 5,
#  'poverti': 74,
#  'level': 54,
#  'fall': 28,
#  'achiev': 0,
#  'global': 38,
#  'recognis': 80,
#  'today': 98,
#  'lack': 52,
#  'self': 87,
#  'confid': 16,
#  'reliant': 81,
#  'assur': 6,
#  'incorrect': 48,
#  'third': 95,
#  'stand': 89,
#  'unless': 103,
#  'strength': 91,
#  'strong': 92,
#  'militari': 60,
#  'power': 75,
#  'also': 2,
#  'econom': 26,
#  'go': 39,
#  'hand': 46,
#  'good': 40,
#  'fortun': 32,
#  'work': 109,
#  'great': 43,
#  'dr': 24,
#  'vikram': 105,
#  'sarabhai': 83,
#  'dept': 20,
#  'space': 88,
#  'professor': 77,
#  'satish': 84,
#  'dhawan': 22,
#  'succeed': 93,
#  'brahm': 8,
#  'prakash': 76,
#  'father': 29,
#  'nuclear': 65,
#  'materi': 58,
#  'lucki': 57,
#  'close': 14,
#  'consid': 18,
#  'opportun': 69,
#  'four': 33,
#  'mileston': 59,
#  'career': 13}
